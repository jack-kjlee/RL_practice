# %% [markdown]
# # Preliminary
# - Experience replay
# - Fixed Target Q-Network
# - Reward clipping
# - Huber loss

# %%
import gym
import numpy as np

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.losses import huber_loss

from collections import deque

import easydict

# %% [markdown]
# # 0. Parameters

# %%
args = easydict.EasyDict({
    "n_episodes": 500,
    "max_steps": 200,
    "success_step_criterion": 190,
    "gamma": 0.99,
    "warmup": 10,
    "epsilon_start": 1.0,
    "epsilon_end": 0.01,
    "epsilon_decay": 0.001,
    "memory_size": 10000,
    "batch_size": 32,
    "learning_rate": 0.001
})

# %% [markdown]
# # 1. Action value function (Q)

# %%
class QNetwork:
    def __init__(self, state_size, action_size, learning_rate):
        self.model = Sequential()
        self.model.add( Dense(16, activation='relu', input_dim=state_size) )
        self.model.add( Dense(16, activation='relu') )
        self.model.add( Dense(16, activation='relu') )
        self.model.add( Dense(action_size, activation='linear') )
        
        self.model.compile(loss=huber_loss, optimizer=Adam(lr=learning_rate))

# %% [markdown]
# # 2. Experience Memory

# %%
class Memory():
    def __init__(self, memory_size):
        self.buffer = deque(maxlen=memory_size)
        
    def add(self, experience):
        self.buffer.append(experience)
        
    def sample(self, batch_size):
        idx = np.random.choice( np.arange(len(self.buffer)), size=batch_size, replace=False )
        return [self.buffer[i] for i in idx]
    
    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # 3. OpenAI Gym Environment

# %%
env = gym.make('CartPole-v0')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

main_QNet = QNetwork(state_size, action_size, args.learning_rate)
target_QNet = QNetwork(state_size, action_size, args.learning_rate)
memory = Memory(args.memory_size)

# %% [markdown]
# # 4. Training

# %%
state = env.reset()
state = np.reshape(state, [1, state_size])

total_step = 0
success_count = 0

for episode in range(1, args.n_episodes+1):    
    target_QNet.model.set_weights(main_QNet.model.get_weights())
    
    #############################################################################################################################
    step = 0
    for _ in range(1, args.max_steps+1):
        step += 1
        total_step += 1
        
        # 1. Choice action
        epsilon = args.epsilon_end + (args.epsilon_start - args.epsilon_end) * np.exp(-args.epsilon_decay * total_step)
        if(epsilon > np.random.rand()):
            action = env.action_space.sample()
        else:
            action - np.argmax(main_QNet.model.predict(state)[0])
            
        # 2. Get next state
        next_state, _, done, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        
        # 3. Finish or keep going
        if(done):
            if(step >= args.success_step_criterion):
                success_count += 1
                reward = 1
            else:
                success_count = 0
                reward = 0
                
            next_state = np.zeros(state.shape)
                
            if(step > args.warmup):
                memory.add((state, action, reward, next_state))
        else:
            reward = 0
            
            if(step > args.warmup):
                memory.add((state, action, reward, next_state))
                
            state = next_state
            
        
        #
        if( len(memory) >= args.batch_size ):
            inputs = np.zeros((args.batch_size, 4))
            targets = np.zeros((args.batch_size, 2))
            
            mini_batch = memory.sample(args.batch_size)
            
            for i, (state_b, action_b, reward_b, next_state_b) in enumerate(mini_batch):
                inputs[i] = state_b
                
                if not( (next_state_b == np.zeros(state_b.shape)).all(axis=1) ):
                    target = reward_b + args.gamma * np.amax(target_QNet.model.predict(next_state_b)[0])
                else:
                    target = reward_b
                    
                targets[i] = main_QNet.model.predict(state_b)
                targets[i][action_b] = target
            
            main_QNet.model.fit(inputs, targets, epochs=1, verbose=0)
            
            
        # Finish
        if(done):
            break
            
    print("Episode: {:02d}, Step: {:03d}, Epsilon: {:.4f}".format(episode, step, epsilon))
    #############################################################################################################################
    
    if(success_count >= 5):
        break
    
    state = env.reset()
    state = np.reshape(state, [1, state_size])
# Out:
# Episode: 01, Step: 014, Epsilon: 0.9862
# Episode: 02, Step: 012, Epsilon: 0.9746
# Episode: 03, Step: 017, Epsilon: 0.9583
# Episode: 04, Step: 021, Epsilon: 0.9386
# Episode: 05, Step: 013, Epsilon: 0.9266
# Episode: 06, Step: 016, Epsilon: 0.9121
# Episode: 07, Step: 015, Epsilon: 0.8987
# Episode: 08, Step: 012, Epsilon: 0.8881
# Episode: 09, Step: 014, Epsilon: 0.8758
# Episode: 10, Step: 015, Epsilon: 0.8630
# Episode: 11, Step: 009, Epsilon: 0.8553
# Episode: 12, Step: 016, Epsilon: 0.8419
# Episode: 13, Step: 018, Epsilon: 0.8271
# Episode: 14, Step: 020, Epsilon: 0.8109
# Episode: 15, Step: 014, Epsilon: 0.7997
# Episode: 16, Step: 022, Epsilon: 0.7826
# Episode: 17, Step: 011, Epsilon: 0.7741
# Episode: 18, Step: 026, Epsilon: 0.7545
# Episode: 19, Step: 015, Epsilon: 0.7434
# Episode: 20, Step: 017, Epsilon: 0.7310
# Episode: 21, Step: 014, Epsilon: 0.7210
# Episode: 22, Step: 018, Epsilon: 0.7083
# Episode: 23, Step: 012, Epsilon: 0.7000
# Episode: 24, Step: 017, Epsilon: 0.6884
# Episode: 25, Step: 021, Epsilon: 0.6743
# Episode: 26, Step: 024, Epsilon: 0.6585
# Episode: 27, Step: 035, Epsilon: 0.6362
# Episode: 28, Step: 014, Epsilon: 0.6275
# Episode: 29, Step: 013, Epsilon: 0.6195
# Episode: 30, Step: 026, Epsilon: 0.6039
# Episode: 31, Step: 010, Epsilon: 0.5980
# Episode: 32, Step: 013, Epsilon: 0.5904
# Episode: 33, Step: 013, Epsilon: 0.5829
# Episode: 34, Step: 027, Epsilon: 0.5676
# Episode: 35, Step: 011, Epsilon: 0.5615
# Episode: 36, Step: 012, Epsilon: 0.5550
# Episode: 37, Step: 020, Epsilon: 0.5442
# Episode: 38, Step: 019, Epsilon: 0.5341
# Episode: 39, Step: 010, Epsilon: 0.5289
# Episode: 40, Step: 023, Epsilon: 0.5171
# Episode: 41, Step: 017, Epsilon: 0.5086
# Episode: 42, Step: 010, Epsilon: 0.5036
# Episode: 43, Step: 010, Epsilon: 0.4987
# Episode: 44, Step: 010, Epsilon: 0.4938
# Episode: 45, Step: 011, Epsilon: 0.4885
# Episode: 46, Step: 011, Epsilon: 0.4833
# Episode: 47, Step: 013, Epsilon: 0.4772
# Episode: 48, Step: 016, Epsilon: 0.4698
# Episode: 49, Step: 010, Epsilon: 0.4652
# Episode: 50, Step: 011, Epsilon: 0.4602
# Episode: 51, Step: 012, Epsilon: 0.4548
# Episode: 52, Step: 026, Epsilon: 0.4434
# Episode: 53, Step: 017, Epsilon: 0.4361
# Episode: 54, Step: 025, Epsilon: 0.4256
# Episode: 55, Step: 014, Epsilon: 0.4198
# Episode: 56, Step: 025, Epsilon: 0.4097
# Episode: 57, Step: 010, Epsilon: 0.4057
# Episode: 58, Step: 037, Epsilon: 0.3913
# Episode: 59, Step: 024, Epsilon: 0.3823
# Episode: 60, Step: 018, Epsilon: 0.3757
# Episode: 61, Step: 008, Epsilon: 0.3727
# Episode: 62, Step: 015, Epsilon: 0.3673
# Episode: 63, Step: 023, Epsilon: 0.3592
# Episode: 64, Step: 009, Epsilon: 0.3561
# Episode: 65, Step: 009, Epsilon: 0.3530
# Episode: 66, Step: 010, Epsilon: 0.3496
# Episode: 67, Step: 010, Epsilon: 0.3462
# Episode: 68, Step: 008, Epsilon: 0.3435
# Episode: 69, Step: 012, Epsilon: 0.3395
# Episode: 70, Step: 009, Epsilon: 0.3366
# Episode: 71, Step: 010, Epsilon: 0.3333
# Episode: 72, Step: 025, Epsilon: 0.3254
# Episode: 73, Step: 042, Epsilon: 0.3124
# Episode: 74, Step: 014, Epsilon: 0.3082
# Episode: 75, Step: 013, Epsilon: 0.3043
# Episode: 76, Step: 012, Epsilon: 0.3008
# Episode: 77, Step: 011, Epsilon: 0.2976
# Episode: 78, Step: 011, Epsilon: 0.2945
# Episode: 79, Step: 010, Epsilon: 0.2917
# Episode: 80, Step: 009, Epsilon: 0.2891
# Episode: 81, Step: 013, Epsilon: 0.2855
# Episode: 82, Step: 037, Epsilon: 0.2755
# Episode: 83, Step: 012, Epsilon: 0.2724
# Episode: 84, Step: 010, Epsilon: 0.2697
# Episode: 85, Step: 010, Epsilon: 0.2672
# Episode: 86, Step: 011, Epsilon: 0.2643
# Episode: 87, Step: 009, Epsilon: 0.2621
# Episode: 88, Step: 009, Epsilon: 0.2598
# Episode: 89, Step: 016, Epsilon: 0.2558
# Episode: 90, Step: 010, Epsilon: 0.2534
# Episode: 91, Step: 030, Epsilon: 0.2462
# Episode: 92, Step: 027, Epsilon: 0.2399
# Episode: 93, Step: 011, Epsilon: 0.2374
# Episode: 94, Step: 009, Epsilon: 0.2354
# Episode: 95, Step: 019, Epsilon: 0.2311
# Episode: 96, Step: 036, Epsilon: 0.2233
# Episode: 97, Step: 031, Epsilon: 0.2168
# Episode: 98, Step: 010, Epsilon: 0.2147
# Episode: 99, Step: 010, Epsilon: 0.2127
# Episode: 100, Step: 010, Epsilon: 0.2107
# Episode: 101, Step: 008, Epsilon: 0.2091
# Episode: 102, Step: 015, Epsilon: 0.2061
# Episode: 103, Step: 022, Epsilon: 0.2018
# Episode: 104, Step: 023, Epsilon: 0.1975
# Episode: 105, Step: 008, Epsilon: 0.1960
# Episode: 106, Step: 010, Epsilon: 0.1941
# Episode: 107, Step: 008, Epsilon: 0.1927
# Episode: 108, Step: 010, Epsilon: 0.1909
# Episode: 109, Step: 010, Epsilon: 0.1891
# Episode: 110, Step: 020, Epsilon: 0.1855
# Episode: 111, Step: 026, Epsilon: 0.1810
# Episode: 112, Step: 011, Epsilon: 0.1791
# Episode: 113, Step: 010, Epsilon: 0.1775
# Episode: 114, Step: 024, Epsilon: 0.1735
# Episode: 115, Step: 014, Epsilon: 0.1712
# Episode: 116, Step: 009, Epsilon: 0.1698
# Episode: 117, Step: 021, Epsilon: 0.1664
# Episode: 118, Step: 012, Epsilon: 0.1646
# Episode: 119, Step: 014, Epsilon: 0.1624
# Episode: 120, Step: 010, Epsilon: 0.1609
# Episode: 121, Step: 008, Epsilon: 0.1597
# Episode: 122, Step: 022, Epsilon: 0.1565
# Episode: 123, Step: 030, Epsilon: 0.1521
# Episode: 124, Step: 011, Epsilon: 0.1506
# Episode: 125, Step: 025, Epsilon: 0.1471
# Episode: 126, Step: 009, Epsilon: 0.1459
# Episode: 127, Step: 010, Epsilon: 0.1445
# Episode: 128, Step: 017, Epsilon: 0.1423
# Episode: 129, Step: 009, Epsilon: 0.1411
# Episode: 130, Step: 009, Epsilon: 0.1399
# Episode: 131, Step: 015, Epsilon: 0.1380
# Episode: 132, Step: 009, Epsilon: 0.1368
# Episode: 133, Step: 016, Epsilon: 0.1348
# Episode: 134, Step: 010, Epsilon: 0.1336
# Episode: 135, Step: 009, Epsilon: 0.1325
# Episode: 136, Step: 009, Epsilon: 0.1314
# Episode: 137, Step: 020, Epsilon: 0.1290
# Episode: 138, Step: 024, Epsilon: 0.1261
# Episode: 139, Step: 010, Epsilon: 0.1250
# Episode: 140, Step: 009, Epsilon: 0.1239
# Episode: 141, Step: 008, Epsilon: 0.1230
# Episode: 142, Step: 009, Epsilon: 0.1220
# Episode: 143, Step: 011, Epsilon: 0.1208
# Episode: 144, Step: 009, Epsilon: 0.1198
# Episode: 145, Step: 008, Epsilon: 0.1189
# Episode: 146, Step: 009, Epsilon: 0.1180
# Episode: 147, Step: 010, Epsilon: 0.1169
# Episode: 148, Step: 037, Epsilon: 0.1130
# Episode: 149, Step: 010, Epsilon: 0.1120
# Episode: 150, Step: 008, Epsilon: 0.1112
# Episode: 151, Step: 008, Epsilon: 0.1104
# Episode: 152, Step: 010, Epsilon: 0.1094
# Episode: 153, Step: 011, Epsilon: 0.1083
# Episode: 154, Step: 010, Epsilon: 0.1073
# Episode: 155, Step: 015, Epsilon: 0.1058
# Episode: 156, Step: 010, Epsilon: 0.1049
# Episode: 157, Step: 010, Epsilon: 0.1039
# Episode: 158, Step: 010, Epsilon: 0.1030
# Episode: 159, Step: 008, Epsilon: 0.1023
# Episode: 160, Step: 009, Epsilon: 0.1014
# Episode: 161, Step: 009, Epsilon: 0.1006
# Episode: 162, Step: 010, Epsilon: 0.0997
# Episode: 163, Step: 013, Epsilon: 0.0986
# Episode: 164, Step: 009, Epsilon: 0.0978
# Episode: 165, Step: 010, Epsilon: 0.0969
# Episode: 166, Step: 009, Epsilon: 0.0961
# Episode: 167, Step: 010, Epsilon: 0.0953
# Episode: 168, Step: 009, Epsilon: 0.0945
# Episode: 169, Step: 009, Epsilon: 0.0937
# Episode: 170, Step: 008, Epsilon: 0.0931
# Episode: 171, Step: 009, Epsilon: 0.0923
# Episode: 172, Step: 009, Epsilon: 0.0916
# Episode: 173, Step: 013, Epsilon: 0.0905
# Episode: 174, Step: 010, Epsilon: 0.0897
# Episode: 175, Step: 010, Epsilon: 0.0889
# Episode: 176, Step: 008, Epsilon: 0.0883
# Episode: 177, Step: 009, Epsilon: 0.0876
# Episode: 178, Step: 008, Epsilon: 0.0870
# Episode: 179, Step: 008, Epsilon: 0.0864
# Episode: 180, Step: 009, Epsilon: 0.0857
# Episode: 181, Step: 009, Epsilon: 0.0850
# Episode: 182, Step: 008, Epsilon: 0.0844
# Episode: 183, Step: 009, Epsilon: 0.0838
# Episode: 184, Step: 010, Epsilon: 0.0830
# Episode: 185, Step: 009, Epsilon: 0.0824
# Episode: 186, Step: 010, Epsilon: 0.0816
# Episode: 187, Step: 010, Epsilon: 0.0809
# Episode: 188, Step: 009, Epsilon: 0.0803
# Episode: 189, Step: 010, Epsilon: 0.0796
# Episode: 190, Step: 024, Epsilon: 0.0779
# Episode: 191, Step: 010, Epsilon: 0.0773
# Episode: 192, Step: 028, Epsilon: 0.0754
# Episode: 193, Step: 010, Epsilon: 0.0748
# Episode: 194, Step: 009, Epsilon: 0.0742
# Episode: 195, Step: 010, Epsilon: 0.0735
# Episode: 196, Step: 008, Epsilon: 0.0730
# Episode: 197, Step: 009, Epsilon: 0.0725
# Episode: 198, Step: 008, Epsilon: 0.0720
# Episode: 199, Step: 009, Epsilon: 0.0714
# Episode: 200, Step: 009, Epsilon: 0.0709
# Episode: 201, Step: 021, Epsilon: 0.0696
# Episode: 202, Step: 018, Epsilon: 0.0685
# Episode: 203, Step: 009, Epsilon: 0.0680
# Episode: 204, Step: 009, Epsilon: 0.0675
# Episode: 205, Step: 010, Epsilon: 0.0669
# Episode: 206, Step: 009, Epsilon: 0.0664
# Episode: 207, Step: 010, Epsilon: 0.0659
# Episode: 208, Step: 009, Epsilon: 0.0654
# Episode: 209, Step: 010, Epsilon: 0.0648
# Episode: 210, Step: 009, Epsilon: 0.0643
# Episode: 211, Step: 014, Epsilon: 0.0636
# Episode: 212, Step: 029, Epsilon: 0.0620
# Episode: 213, Step: 011, Epsilon: 0.0615
# Episode: 214, Step: 009, Epsilon: 0.0610
# Episode: 215, Step: 009, Epsilon: 0.0605
# Episode: 216, Step: 010, Epsilon: 0.0600
# Episode: 217, Step: 011, Epsilon: 0.0595
# Episode: 218, Step: 010, Epsilon: 0.0590
# Episode: 219, Step: 009, Epsilon: 0.0586
# Episode: 220, Step: 009, Epsilon: 0.0581
# Episode: 221, Step: 008, Epsilon: 0.0577
# Episode: 222, Step: 009, Epsilon: 0.0573
# Episode: 223, Step: 009, Epsilon: 0.0569
# Episode: 224, Step: 017, Epsilon: 0.0561
# Episode: 225, Step: 010, Epsilon: 0.0556
# Episode: 226, Step: 009, Epsilon: 0.0552
# Episode: 227, Step: 008, Epsilon: 0.0549
# Episode: 228, Step: 008, Epsilon: 0.0545
# Episode: 229, Step: 009, Epsilon: 0.0541
# Episode: 230, Step: 010, Epsilon: 0.0537
# Episode: 231, Step: 008, Epsilon: 0.0533
# Episode: 232, Step: 010, Epsilon: 0.0529
# Episode: 233, Step: 009, Epsilon: 0.0525
# Episode: 234, Step: 009, Epsilon: 0.0521
# Episode: 235, Step: 009, Epsilon: 0.0518
# Episode: 236, Step: 009, Epsilon: 0.0514
# Episode: 237, Step: 021, Epsilon: 0.0505
# Episode: 238, Step: 010, Epsilon: 0.0501
# Episode: 239, Step: 008, Epsilon: 0.0498
# Episode: 240, Step: 010, Epsilon: 0.0494
# Episode: 241, Step: 008, Epsilon: 0.0491
# Episode: 242, Step: 013, Epsilon: 0.0486
# Episode: 243, Step: 008, Epsilon: 0.0483
# Episode: 244, Step: 010, Epsilon: 0.0479
# Episode: 245, Step: 009, Epsilon: 0.0476
# Episode: 246, Step: 008, Epsilon: 0.0473
# Episode: 247, Step: 011, Epsilon: 0.0468
# Episode: 248, Step: 015, Epsilon: 0.0463
# Episode: 249, Step: 008, Epsilon: 0.0460
# Episode: 250, Step: 009, Epsilon: 0.0457
# Episode: 251, Step: 010, Epsilon: 0.0453
# Episode: 252, Step: 009, Epsilon: 0.0450
# Episode: 253, Step: 010, Epsilon: 0.0447
# Episode: 254, Step: 010, Epsilon: 0.0443
# Episode: 255, Step: 010, Epsilon: 0.0440
# Episode: 256, Step: 009, Epsilon: 0.0437
# Episode: 257, Step: 009, Epsilon: 0.0434
# Episode: 258, Step: 009, Epsilon: 0.0431
# Episode: 259, Step: 009, Epsilon: 0.0428
# Episode: 260, Step: 008, Epsilon: 0.0425
# Episode: 261, Step: 008, Epsilon: 0.0423
# Episode: 262, Step: 010, Epsilon: 0.0419
# Episode: 263, Step: 008, Epsilon: 0.0417
# Episode: 264, Step: 010, Epsilon: 0.0414
# Episode: 265, Step: 009, Epsilon: 0.0411
# Episode: 266, Step: 009, Epsilon: 0.0408
# Episode: 267, Step: 009, Epsilon: 0.0405
# Episode: 268, Step: 009, Epsilon: 0.0403
# Episode: 269, Step: 009, Epsilon: 0.0400
# Episode: 270, Step: 010, Epsilon: 0.0397
# Episode: 271, Step: 010, Epsilon: 0.0394
# Episode: 272, Step: 008, Epsilon: 0.0392
# Episode: 273, Step: 009, Epsilon: 0.0389
# Episode: 274, Step: 009, Epsilon: 0.0386
# Episode: 275, Step: 009, Epsilon: 0.0384
# Episode: 276, Step: 010, Epsilon: 0.0381
# Episode: 277, Step: 010, Epsilon: 0.0378
# Episode: 278, Step: 009, Epsilon: 0.0376
# Episode: 279, Step: 009, Epsilon: 0.0373
# Episode: 280, Step: 011, Epsilon: 0.0370
# Episode: 281, Step: 010, Epsilon: 0.0368
# Episode: 282, Step: 009, Epsilon: 0.0365
# Episode: 283, Step: 010, Epsilon: 0.0363
# Episode: 284, Step: 009, Epsilon: 0.0360
# Episode: 285, Step: 009, Epsilon: 0.0358
# Episode: 286, Step: 009, Epsilon: 0.0356
# Episode: 287, Step: 009, Epsilon: 0.0353
# Episode: 288, Step: 008, Epsilon: 0.0351
# Episode: 289, Step: 010, Epsilon: 0.0349
# Episode: 290, Step: 009, Epsilon: 0.0346
# Episode: 291, Step: 009, Epsilon: 0.0344
# Episode: 292, Step: 011, Epsilon: 0.0342
# Episode: 293, Step: 013, Epsilon: 0.0338
# Episode: 294, Step: 010, Epsilon: 0.0336
# Episode: 295, Step: 011, Epsilon: 0.0334
# Episode: 296, Step: 008, Epsilon: 0.0332
# Episode: 297, Step: 028, Epsilon: 0.0325
# Episode: 298, Step: 010, Epsilon: 0.0323
# Episode: 299, Step: 009, Epsilon: 0.0321
# Episode: 300, Step: 009, Epsilon: 0.0319
# Episode: 301, Step: 008, Epsilon: 0.0317
# Episode: 302, Step: 009, Epsilon: 0.0315
# Episode: 303, Step: 010, Epsilon: 0.0313
# Episode: 304, Step: 009, Epsilon: 0.0311
# Episode: 305, Step: 009, Epsilon: 0.0309
# Episode: 306, Step: 009, Epsilon: 0.0308
# Episode: 307, Step: 009, Epsilon: 0.0306
# Episode: 308, Step: 009, Epsilon: 0.0304
# Episode: 309, Step: 010, Epsilon: 0.0302
# Episode: 310, Step: 010, Epsilon: 0.0300
# Episode: 311, Step: 009, Epsilon: 0.0298
# Episode: 312, Step: 010, Epsilon: 0.0296
# Episode: 313, Step: 010, Epsilon: 0.0294
# Episode: 314, Step: 009, Epsilon: 0.0292
# Episode: 315, Step: 009, Epsilon: 0.0291
# Episode: 316, Step: 009, Epsilon: 0.0289
# Episode: 317, Step: 009, Epsilon: 0.0287
# Episode: 318, Step: 010, Epsilon: 0.0285
# Episode: 319, Step: 010, Epsilon: 0.0284
# Episode: 320, Step: 009, Epsilon: 0.0282
# Episode: 321, Step: 010, Epsilon: 0.0280
# Episode: 322, Step: 011, Epsilon: 0.0278
# Episode: 323, Step: 010, Epsilon: 0.0276
# Episode: 324, Step: 010, Epsilon: 0.0275
# Episode: 325, Step: 009, Epsilon: 0.0273
# Episode: 326, Step: 009, Epsilon: 0.0271
# Episode: 327, Step: 010, Epsilon: 0.0270
# Episode: 328, Step: 010, Epsilon: 0.0268
# Episode: 329, Step: 019, Epsilon: 0.0265
# Episode: 330, Step: 009, Epsilon: 0.0263
# Episode: 331, Step: 010, Epsilon: 0.0262
# Episode: 332, Step: 010, Epsilon: 0.0260
# Episode: 333, Step: 009, Epsilon: 0.0259
# Episode: 334, Step: 010, Epsilon: 0.0257
# Episode: 335, Step: 008, Epsilon: 0.0256
# Episode: 336, Step: 010, Epsilon: 0.0254
# Episode: 337, Step: 010, Epsilon: 0.0253
# Episode: 338, Step: 009, Epsilon: 0.0251
# Episode: 339, Step: 010, Epsilon: 0.0250
# Episode: 340, Step: 009, Epsilon: 0.0249
# Episode: 341, Step: 009, Epsilon: 0.0247
# Episode: 342, Step: 008, Epsilon: 0.0246
# Episode: 343, Step: 009, Epsilon: 0.0245
# Episode: 344, Step: 010, Epsilon: 0.0243
# Episode: 345, Step: 010, Epsilon: 0.0242
# Episode: 346, Step: 008, Epsilon: 0.0241
# Episode: 347, Step: 009, Epsilon: 0.0240
# Episode: 348, Step: 009, Epsilon: 0.0238
# Episode: 349, Step: 009, Epsilon: 0.0237
# Episode: 350, Step: 009, Epsilon: 0.0236
# Episode: 351, Step: 009, Epsilon: 0.0235
# Episode: 352, Step: 008, Epsilon: 0.0234
# Episode: 353, Step: 009, Epsilon: 0.0232
# Episode: 354, Step: 009, Epsilon: 0.0231
# Episode: 355, Step: 010, Epsilon: 0.0230
# Episode: 356, Step: 009, Epsilon: 0.0229
# Episode: 357, Step: 008, Epsilon: 0.0228
# Episode: 358, Step: 010, Epsilon: 0.0226
# Episode: 359, Step: 010, Epsilon: 0.0225
# Episode: 360, Step: 010, Epsilon: 0.0224
# Episode: 361, Step: 010, Epsilon: 0.0223
# Episode: 362, Step: 008, Epsilon: 0.0222
# Episode: 363, Step: 009, Epsilon: 0.0221
# Episode: 364, Step: 008, Epsilon: 0.0220
# Episode: 365, Step: 010, Epsilon: 0.0218
# Episode: 366, Step: 010, Epsilon: 0.0217
# Episode: 367, Step: 009, Epsilon: 0.0216
# Episode: 368, Step: 010, Epsilon: 0.0215
# Episode: 369, Step: 010, Epsilon: 0.0214
# Episode: 370, Step: 010, Epsilon: 0.0213
# Episode: 371, Step: 009, Epsilon: 0.0212
# Episode: 372, Step: 009, Epsilon: 0.0211
# Episode: 373, Step: 011, Epsilon: 0.0210
# Episode: 374, Step: 009, Epsilon: 0.0209
# Episode: 375, Step: 018, Epsilon: 0.0207
# Episode: 376, Step: 010, Epsilon: 0.0206
# Episode: 377, Step: 009, Epsilon: 0.0205
# Episode: 378, Step: 010, Epsilon: 0.0204
# Episode: 379, Step: 011, Epsilon: 0.0202
# Episode: 380, Step: 012, Epsilon: 0.0201
# Episode: 381, Step: 009, Epsilon: 0.0200
# Episode: 382, Step: 009, Epsilon: 0.0199
# Episode: 383, Step: 009, Epsilon: 0.0199
# Episode: 384, Step: 010, Epsilon: 0.0198
# Episode: 385, Step: 009, Epsilon: 0.0197
# Episode: 386, Step: 010, Epsilon: 0.0196
# Episode: 387, Step: 009, Epsilon: 0.0195
# Episode: 388, Step: 009, Epsilon: 0.0194
# Episode: 389, Step: 009, Epsilon: 0.0193
# Episode: 390, Step: 008, Epsilon: 0.0192
# Episode: 391, Step: 009, Epsilon: 0.0192
# Episode: 392, Step: 009, Epsilon: 0.0191
# Episode: 393, Step: 008, Epsilon: 0.0190
# Episode: 394, Step: 010, Epsilon: 0.0189
# Episode: 395, Step: 009, Epsilon: 0.0188
# Episode: 396, Step: 010, Epsilon: 0.0187
# Episode: 397, Step: 010, Epsilon: 0.0187
# Episode: 398, Step: 008, Epsilon: 0.0186
# Episode: 399, Step: 010, Epsilon: 0.0185
# Episode: 400, Step: 010, Epsilon: 0.0184
# Episode: 401, Step: 008, Epsilon: 0.0184
# Episode: 402, Step: 008, Epsilon: 0.0183
# Episode: 403, Step: 009, Epsilon: 0.0182
# Episode: 404, Step: 008, Epsilon: 0.0181
# Episode: 405, Step: 009, Epsilon: 0.0181
# Episode: 406, Step: 010, Epsilon: 0.0180
# Episode: 407, Step: 010, Epsilon: 0.0179
# Episode: 408, Step: 009, Epsilon: 0.0178
# Episode: 409, Step: 009, Epsilon: 0.0178
# Episode: 410, Step: 009, Epsilon: 0.0177
# Episode: 411, Step: 009, Epsilon: 0.0176
# Episode: 412, Step: 009, Epsilon: 0.0176
# Episode: 413, Step: 010, Epsilon: 0.0175
# Episode: 414, Step: 009, Epsilon: 0.0174
# Episode: 415, Step: 009, Epsilon: 0.0174
# Episode: 416, Step: 010, Epsilon: 0.0173
# Episode: 417, Step: 010, Epsilon: 0.0172
# Episode: 418, Step: 010, Epsilon: 0.0171
# Episode: 419, Step: 010, Epsilon: 0.0171
# Episode: 420, Step: 008, Epsilon: 0.0170
# Episode: 421, Step: 009, Epsilon: 0.0169
# Episode: 422, Step: 010, Epsilon: 0.0169
# Episode: 423, Step: 009, Epsilon: 0.0168
# Episode: 424, Step: 009, Epsilon: 0.0168
# Episode: 425, Step: 010, Epsilon: 0.0167
# Episode: 426, Step: 009, Epsilon: 0.0166
# Episode: 427, Step: 009, Epsilon: 0.0166
# Episode: 428, Step: 009, Epsilon: 0.0165
# Episode: 429, Step: 010, Epsilon: 0.0164
# Episode: 430, Step: 009, Epsilon: 0.0164
# Episode: 431, Step: 009, Epsilon: 0.0163
# Episode: 432, Step: 009, Epsilon: 0.0163
# Episode: 433, Step: 010, Epsilon: 0.0162
# Episode: 434, Step: 010, Epsilon: 0.0162
# Episode: 435, Step: 009, Epsilon: 0.0161
# Episode: 436, Step: 010, Epsilon: 0.0160
# Episode: 437, Step: 009, Epsilon: 0.0160
# Episode: 438, Step: 010, Epsilon: 0.0159
# Episode: 439, Step: 010, Epsilon: 0.0159
# Episode: 440, Step: 010, Epsilon: 0.0158
# Episode: 441, Step: 009, Epsilon: 0.0158
# Episode: 442, Step: 010, Epsilon: 0.0157
# Episode: 443, Step: 010, Epsilon: 0.0156
# Episode: 444, Step: 008, Epsilon: 0.0156
# Episode: 445, Step: 010, Epsilon: 0.0155
# Episode: 446, Step: 010, Epsilon: 0.0155
# Episode: 447, Step: 010, Epsilon: 0.0154
# Episode: 448, Step: 010, Epsilon: 0.0154
# Episode: 449, Step: 010, Epsilon: 0.0153
# Episode: 450, Step: 010, Epsilon: 0.0153
# Episode: 451, Step: 008, Epsilon: 0.0152
# Episode: 452, Step: 008, Epsilon: 0.0152
# Episode: 453, Step: 008, Epsilon: 0.0151
# Episode: 454, Step: 010, Epsilon: 0.0151
# Episode: 455, Step: 009, Epsilon: 0.0150
# Episode: 456, Step: 009, Epsilon: 0.0150
# Episode: 457, Step: 009, Epsilon: 0.0150
# Episode: 458, Step: 010, Epsilon: 0.0149
# Episode: 459, Step: 009, Epsilon: 0.0149
# Episode: 460, Step: 009, Epsilon: 0.0148
# Episode: 461, Step: 010, Epsilon: 0.0148
# Episode: 462, Step: 008, Epsilon: 0.0147
# Episode: 463, Step: 010, Epsilon: 0.0147
# Episode: 464, Step: 010, Epsilon: 0.0146
# Episode: 465, Step: 010, Epsilon: 0.0146
# Episode: 466, Step: 011, Epsilon: 0.0145
# Episode: 467, Step: 010, Epsilon: 0.0145
# Episode: 468, Step: 009, Epsilon: 0.0145
# Episode: 469, Step: 009, Epsilon: 0.0144
# Episode: 470, Step: 010, Epsilon: 0.0144
# Episode: 471, Step: 009, Epsilon: 0.0143
# Episode: 472, Step: 018, Epsilon: 0.0143
# Episode: 473, Step: 010, Epsilon: 0.0142
# Episode: 474, Step: 010, Epsilon: 0.0142
# Episode: 475, Step: 010, Epsilon: 0.0141
# Episode: 476, Step: 009, Epsilon: 0.0141
# Episode: 477, Step: 008, Epsilon: 0.0141
# Episode: 478, Step: 008, Epsilon: 0.0140
# Episode: 479, Step: 008, Epsilon: 0.0140
# Episode: 480, Step: 009, Epsilon: 0.0140
# Episode: 481, Step: 010, Epsilon: 0.0139
# Episode: 482, Step: 010, Epsilon: 0.0139
# Episode: 483, Step: 009, Epsilon: 0.0138
# Episode: 484, Step: 010, Epsilon: 0.0138
# Episode: 485, Step: 010, Epsilon: 0.0138
# Episode: 486, Step: 009, Epsilon: 0.0137
# Episode: 487, Step: 009, Epsilon: 0.0137
# Episode: 488, Step: 010, Epsilon: 0.0137
# Episode: 489, Step: 010, Epsilon: 0.0136
# Episode: 490, Step: 011, Epsilon: 0.0136
# Episode: 491, Step: 008, Epsilon: 0.0136
# Episode: 492, Step: 009, Epsilon: 0.0135
# Episode: 493, Step: 009, Epsilon: 0.0135
# Episode: 494, Step: 011, Epsilon: 0.0135
# Episode: 495, Step: 009, Epsilon: 0.0134
# Episode: 496, Step: 009, Epsilon: 0.0134
# Episode: 497, Step: 010, Epsilon: 0.0134
# Episode: 498, Step: 010, Epsilon: 0.0133
# Episode: 499, Step: 009, Epsilon: 0.0133
# Episode: 500, Step: 011, Epsilon: 0.0133
